# %%
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd 
df = pd.read_csv('/home/xternava/Documents/GitHub/x264/measures/stats_size_gadgets_10.csv')
df12= df.drop([0], axis=0)
all_data1 = df12['Binary_size']
labels1 = 'Binary size'
all_data2 = df12['All_gadgets']
labels2 = 'Number of gadgets'

plt.rc('font', size=10) 

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(5, 3))

# rectangular box plot
#bplot1 = ax1.boxplot(all_data1,
#                     vert=True,  # vertical box alignment
#                     patch_artist=True,  # fill with color
#                     labels=labels1, widths=(0.5))  # will be used to label x-ticks
#ax1.set_title('Binary size')
#ax1.set_xlabel('Binary size')
ax1.scatter(1,3096176, marker ="*", color="red", s=100)
#ax1.margins(x=0)
vplot1 = ax1.violinplot(all_data1)
ax1.set_xlabel(labels1)

# notch shape box plot
#bplot2 = ax2.boxplot(all_data2,
#                     # notch=True,  # notch shape
#                     vert=True,  # vertical box alignment
#                     patch_artist=True,  # fill with color
#                     labels=labels2, widths=(0.5))  # will be used to label x-ticks
#ax2.set_title('Number of gadgets')
#ax2.set_xlabel('Number of gadgets')
ax2.scatter(1,106495, marker ="*", color="red", s=100)
vplot2 = ax2.violinplot(all_data2)
ax2.set_xlabel(labels2)

for pc in vplot1['bodies']:
    pc.set_facecolor('purple')

# fill with colors
#colors = ['lightblue', 'lightgreen', 'pink']
#for bplot in (bplot1, bplot2):
#    for patch, color in zip(bplot['bodies'], colors):
#        patch.set_facecolor(color)


fig.tight_layout(pad=1.0)
ax1.grid(which='both', axis='y')
ax2.grid(which='both', axis='y')
plt.savefig("binarysizegadgets.pdf", bbox_inches = 'tight', pad_inches = 0)

plt.show()

# %%
import pandas as pd 
df2 = pd.read_csv('/home/xternava/Documents/GitHub/x264/measures/stats_size_gadgets_10.csv')

df2.loc[:,'DifferenceB'] = ((1 - (df2.Binary_size / df2.iloc[0][1]))*100).round(4)
df2.loc[:,'DifferenceG'] = ((1 - (df2.All_gadgets / df2.iloc[0][2]))*100).round(4)
print(df2)
# Out:
#                                       Specialized_sys  Binary_size  \
# 0                                            BASELINE      3096176
# 1                                         ['PSY_YES']      3096144
# 2   ['PSY_NO', 'MIXED_REFS_YES', 'CABAC_YES', 'MBT...      2899104
# 3   ['CABAC_NO', 'MBTREE_NO', 'WEIGHTB_NO', 'PSY_N...      2982872
# 4                                      ['MBTREE_YES']      3079360
# 5   ['MIXED_REFS_NO', 'CABAC_NO', 'MBTREE_NO', 'WE...      2986992
# 6   ['MIXED_REFS_NO', 'CABAC_NO', 'MBTREE_NO', 'WE...      2986992
# 7                                        ['CABAC_NO']      2995424
# 8                                       ['MBTREE_NO']      3096144
# 9   ['MIXED_REFS_NO', 'CABAC_NO', 'MBTREE_NO', 'WE...      2986992
# 10                                      ['CABAC_YES']      2928488
# 11                                  ['MIXED_REFS_NO']      3087808
# 12                                 ['MIXED_REFS_YES']      3083696
# 13                                    ['WEIGHTB_YES']      3096096
# 14                                     ['WEIGHTB_NO']      3096144
# 15  ['CABAC_NO', 'MBTREE_NO', 'WEIGHTB_NO', 'PSY_N...      2982872
# 16  ['CABAC_NO', 'WEIGHTB_NO', 'PSY_NO', 'MIXED_RE...      2966088
# 17  ['MIXED_REFS_NO', 'CABAC_NO', 'MBTREE_NO', 'WE...      2986992
# 18                                         ['PSY_NO']      3096144
# 19  ['MIXED_REFS_NO', 'CABAC_NO', 'MBTREE_NO', 'WE...      2986992
# 20  ['MIXED_REFS_NO', 'CABAC_NO', 'MBTREE_NO', 'WE...      2986992
#
#     All_gadgets  ROP_gadgets  JOP_gadgets  SYS_gadgets  DifferenceB  \
# 0        106495        23146        84121            3       0.0000
# 1        106689        23234        84210            2       0.0010
# 2         98852        22164        77395            8       6.3650
# 3        101777        22472        80075            9       3.6595
# 4        105636        23117        83252           15       0.5431
# 5        101859        22426        80210           13       3.5264
# 6        101859        22426        80210           13       3.5264
# 7        102232        22485        80541            4       3.2541
# 8        106682        23237        84207            5       0.0010
# 9        101859        22426        80210           13       3.5264
# 10        99464        22535        77627           10       5.4160
# 11       105957        23195        83536            7       0.2703
# 12       106807        23014        84556            4       0.4031
# 13       106550        23143        84177            3       0.0026
# 14       106470        23195        84036            4       0.0010
# 15       101777        22472        80075            9       3.6595
# 16       101302        22279        79794            5       4.2016
# 17       101859        22426        80210           13       3.5264
# 18       106943        23362        84329            7       0.0010
# 19       101859        22426        80210           13       3.5264
# 20       101859        22426        80210           13       3.5264
#
#     DifferenceG
# 0        0.0000
# 1       -0.1822
# 2        7.1769
# 3        4.4303
# 4        0.8066
# 5        4.3533
# 6        4.3533
# 7        4.0030
# 8       -0.1756
# 9        4.3533
# 10       6.6022
# 11       0.5052
# 12      -0.2930
# 13      -0.0516
# 14       0.0235
# 15       4.4303
# 16       4.8763
# 17       4.3533
# 18      -0.4207
# 19       4.3533
# 20       4.3533
