# %%
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd 
df = pd.read_csv('/home/xternava/Documents/GitHub/x264/measures/stats_size_gadgets_10.csv')
df12= df.drop([0], axis=0)
all_data1 = df12['ROP_gadgets']
labels1 = 'ROP gadgets'
all_data2 = df12['JOP_gadgets']
labels2 = 'JOP gadgets'
all_data3 = df12['SYS_gadgets']
labels3 = 'SYS gadgets'
     
plt.rc('font', size=10) 

fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(5, 3))

# rectangular box plot
#bplot1 = ax1.boxplot(all_data1,
#                     vert=True,  # vertical box alignment
#                     patch_artist=True,  # fill with color
#                     labels=labels1, widths=(0.5))  # will be used to label x-ticks
#ax1.set_title('Binary size')
#ax1.set_xlabel('Binary size')
ax1.scatter(1,23146, marker ="*", color="red", s=100)
ax1.violinplot(all_data1)
ax1.set_xlabel(labels1)
                    
# notch shape box plot
#bplot2 = ax2.boxplot(all_data2,
#                     # notch=True,  # notch shape
#                     vert=True,  # vertical box alignment
#                     patch_artist=True,  # fill with color
#                     labels=labels2, widths=(0.5))  # will be used to label x-ticks
#ax2.set_title('Number of gadgets')
#ax2.set_xlabel('Number of gadgets')
ax2.scatter(1,84121, marker ="*", color="red", s=100)
ax2.violinplot(all_data2)
ax2.set_xlabel(labels2)

# notch shape box plot
#bplot3 = ax3.boxplot(all_data3,
#                     # notch=True,  # notch shape
#                     vert=True,  # vertical box alignment
#                     patch_artist=True,  # fill with color
#                     labels=labels3, widths=(0.5))  # will be used to label x-ticks
#ax2.set_title('Number of gadgets')
#ax2.set_xlabel('Number of gadgets')
ax3.scatter(1,3, marker ="*", color="red", s=100)
ax3.violinplot(all_data3)
ax3.set_xlabel(labels3)

# fill with colors
#colors = ['pink', 'lightgreen', 'lightblue']
#for bplot in (bplot1, bplot2, bplot3):
#    for patch, color in zip(bplot['boxes'], colors):
#        patch.set_facecolor(color)

fig.tight_layout(pad=1.0)
ax1.grid(which='both', axis='y')
ax2.grid(which='both', axis='y')
ax3.grid(which='both', axis='y')
plt.savefig("gadgets3.pdf", bbox_inches = 'tight', pad_inches = 0)

plt.show()
